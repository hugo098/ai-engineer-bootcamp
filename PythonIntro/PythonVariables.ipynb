# %%
x = 10
x
# Out:
# 10

# %%
(a, b, c, d) = 10, 20, 30, 40
print(b)
print(d)
# Out:
# 20
# 40

# %%
a = True
type(a)
# Out:
# bool

# %%
b = 99
type(b)
# Out:
# int

# %%
type(0.99)
# Out:
# float

# %%
b = 99
b = float(b)
type(b)
# Out:
# float

# %%
int(0.99)
# Out:
# 0

# %%
m = 100
print(str(m) + ' days')
# Out:
# 100 days

# %%
print("It's cool, isn't it?")
# Out:
# It's cool, isn't it?
