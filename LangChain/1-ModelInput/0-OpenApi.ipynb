# %%
import openai
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPENAI_API_KEY")

# %%
openai.api_key = api_key

# %%
client = openai.OpenAI()

# %%
completion = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        # {"role": "system", "content": "You are Marv, a sarcastic chatbot."},
        {
            "role": "user",
            "content": "Can you explain what a black hole is?",
        },
    ],
    max_completion_tokens=250,
    temperature=0,
    seed=42,
    stream=True,
)

# %%
completion

# %%
for i in completion:
    print(i.choices[0].delta.content, end="")
# Out:
# Certainly! A **black hole** is a region in space where gravity is so strong that nothing, not even light, can escape from it. This intense gravitational pull occurs because a massive amount of matter has been compressed into a very small area.
#
# Here’s a bit more detail:
#
# - **Formation:** Black holes typically form when massive stars run out of fuel and collapse under their own gravity during a supernova explosion. The core shrinks to a point of infinite density called a **singularity**.
#
# - **Event Horizon:** Surrounding the singularity is the **event horizon**, which is the boundary beyond which nothing can return. Once something crosses this boundary, it inevitably falls into the singularity.
#
# - **Types:** There are different types of black holes, including:
#   - **Stellar black holes:** Formed from collapsing stars.
#   - **Supermassive black holes:** Found at the centers of galaxies, with masses millions or billions of times that of the Sun.
# ...

# %%
print(completion.choices[0].message.content)
# Out:
# Certainly! A **black hole** is a region in space where gravity is so strong that nothing, not even light, can escape from it. This intense gravitational pull occurs because a large amount of mass has been compressed into an incredibly small area, causing space-time to bend sharply.
#
# Black holes typically form when massive stars exhaust their nuclear fuel and undergo a supernova explosion, collapsing under their own gravity. The boundary around a black hole from which nothing can escape is called the **event horizon**. Anything that crosses this boundary is irretrievably pulled inside.
#
# There are different types of black holes based on their size, including:
#
# ...

# %%
tweet_classifier = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant that classifies tweets into categories.",
        },
        {
            "role": "user",
            "content": "Classify the following tweet: 'Just had the best coffee ever! #coffee #morning'",
        },
    ],
)

# %%
print(tweet_classifier.choices[0].message.content)
# Out:
# The tweet can be classified into the category: Food & Drink.

# %%
tweet_classifier = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant that classifies tweets into based on Postive, Negative, and Neutral sentiments.",
        },
        {
            "role": "user",
            "content": "Classify the following tweet: 'Just had the mid coffee ever! #coffee #morning'",
        },
    ],
)

# %%
print(tweet_classifier.choices[0].message.content)
# Out:
# The tweet "Just had the mid coffee ever! #coffee #morning" appears to have a typo and likely meant to say "Just had the best coffee ever!" Assuming this, the sentiment is Positive. If the typo is taken literally as "mid," which sometimes means average or mediocre, the sentiment would be Neutral.
#
# Overall, the most probable classification is: Neutral.
