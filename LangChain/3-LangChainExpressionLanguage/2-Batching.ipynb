# %% [markdown]
# ### Batching

# %%
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# %%
chat_template = ChatPromptTemplate.from_messages(
    [
        (
            "human",
            "I have recently adopted a {pet} which is a {breed}. Coul you suggest several training tips?",
        )
    ]
)

# %%
chat = ChatOpenAI(
    api_key=api_key,
    model_name="gpt-4.1-mini",
    temperature=0,
    max_tokens=100,
    seed=42,
)

# %%
chain = chat_template | chat

# %%
chain.invoke({"pet": "dog", "breed": "Golden Retriever"})
# Out:
# AIMessage(content='Congratulations on your new Golden Retriever! They are intelligent, friendly, and eager to please, which makes them great candidates for training. Here are several training tips to help you get started:\n\n1. **Start Early and Be Consistent**  \n   Begin training as soon as you bring your dog home. Consistency is key—use the same commands and routines every day to help your dog understand what you expect.\n\n2. **Use Positive Reinforcement**  \n   Reward good behavior with treats, praise,', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 26, 'total_tokens': 126, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_376a7ccef1', 'id': 'chatcmpl-CqPdcu1xRlE2ZdGlrCFKp4fhoSsF4', 'service_
# ...

# %%
# %%time
chain.batch(
    [
        {"pet": "dog", "breed": "Golden Retriever"},
        {"pet": "cat", "breed": "Siamese"},
    ]
)
# Out:
# CPU times: user 12 ms, sys: 3.43 ms, total: 15.4 ms
# Wall time: 2.69 s
# ...

# %%
# %%time
chain.invoke({"pet": "cat", "breed": "Siamese"})
# Out:
# CPU times: user 3.64 ms, sys: 1.63 ms, total: 5.26 ms
# Wall time: 2.4 s
# ...

# %%
# %%time
chain.invoke({"pet": "dog", "breed": "Golden Retriever"})
# Out:
# CPU times: user 5.91 ms, sys: 2.02 ms, total: 7.93 ms
# Wall time: 2.13 s
# ...
