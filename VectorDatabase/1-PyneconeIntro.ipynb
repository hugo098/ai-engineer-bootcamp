# %%
import pinecone
from pinecone import Pinecone, ServerlessSpec
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
pc = Pinecone(
    api_key=os.environ.get("PINECONE_API_KEY"),
    environment=os.environ.get("PINECONE_ENV"),
)

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "my-index-2",
#         "metric": "dotproduct",
#         "host": "my-index-2-h2xw5gc.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1536,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
pc.create_index(
    name="my-index-2",
    dimension=1536,
    metric="dotproduct",
    spec=ServerlessSpec(region="us-east-1", cloud="aws"),
)
# Out:
# {
#     "name": "my-index-2",
#     "metric": "dotproduct",
#     "host": "my-index-2-h2xw5gc.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 1536,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "access-control-allow-origin": "*",
#             "vary": "origin,access-control-request-method,access-control-request-headers",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "e480139ce95b27f2142e6bd7bddf5ce4",
#             "date": "Sat, 03 Jan 2026 14:00:14 GMT",
#             "server": "Google Frontend",
#             "content-length": "394",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
index_name = "example-index"
dimesion = 3
metric = "cosine"

# %%
if index_name in [index.name for index in pc.list_indexes()]:
    print(f"Index '{index_name}' already exists.")
    pc.delete_index(index_name)
    print(f"Index '{index_name}' deleted.")
else:
    print(f"Index '{index_name}' does not exist.")
# Out:
# Index 'my-index-2' already exists.
# Index 'my-index-2' deleted.

# %%
pc.list_indexes()
# Out:
# []

# %%
pc.create_index(
    name="example-index",
    dimension=dimesion,
    metric=metric,
    spec=ServerlessSpec(region="us-east-1", cloud="aws"),
)
# Out:
# {
#     "name": "example-index",
#     "metric": "cosine",
#     "host": "example-index-h2xw5gc.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 3,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "access-control-allow-origin": "*",
#             "vary": "origin,access-control-request-method,access-control-request-headers",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "71591cdd2782e608f3ad38d361a03d55",
#             "date": "Sat, 03 Jan 2026 14:30:28 GMT",
#             "server": "Google Frontend",
#             "content-length": "393",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
metric = "dotproduct"
dimesion = 1536

pc.create_index(
    name="index-1536-dotproduct",
    dimension=dimesion,
    metric=metric,
    spec=ServerlessSpec(region="us-east-1", cloud="aws"),
)
# Out:
# {
#     "name": "index-1536-dotproduct",
#     "metric": "dotproduct",
#     "host": "index-1536-dotproduct-h2xw5gc.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 1536,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "access-control-allow-origin": "*",
#             "vary": "origin,access-control-request-method,access-control-request-headers",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "2f9a7a4f5bb1fa4561203cf89618af84",
#             "date": "Sat, 03 Jan 2026 14:31:26 GMT",
#             "server": "Google Frontend",
#             "content-length": "416",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "index-1536-dotproduct",
#         "metric": "dotproduct",
#         "host": "index-1536-dotproduct-h2xw5gc.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1536,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "example-index",
#         "metric": "cosine",
#         "host": "example-index-h2xw5gc.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 3,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
index = pc.Index(index_name)

# %%
index.upsert(
    [
        ("dog", [4.0, 0.0, 1.0]),
        ("cat", [4.0, 0.0, 0.0]),
        ("chicken", [0.3, 0.0, 0.0]),
        ("cow", [0.4, 0.0, 0.1]),
        ("horse", [0.5, 0.0, 0.2]),
    ]
)
# Out:
# UpsertResponse(upserted_count=5, _response_info={'raw_headers': {'date': 'Sat, 03 Jan 2026 14:53:45 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '1', 'x-pinecone-request-logical-size': '81', 'x-pinecone-request-latency-ms': '248', 'x-pinecone-request-id': '8417296144727745417', 'x-envoy-upstream-service-time': '249', 'x-pinecone-response-duration-ms': '250', 'grpc-status': '0', 'server': 'envoy'}})
