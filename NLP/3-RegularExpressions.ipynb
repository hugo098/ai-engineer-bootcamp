# %% [markdown]
# ## Regular Expressions

# %%
import re

# %%
folder = r"C:\desk\notes"
print(folder)
# Out:
# C:\desk\notes

# %%
result_search = re.search("pattern", r"string pattern")

# %%
print(result_search)
# Out:
# <re.Match object; span=(7, 14), match='pattern'>

# %%
result_search_2 = re.search("pattern", r"none p")
print(result_search_2)
# Out:
# None

# %%
string = r"sara"

# %%
new_string = re.sub("sara", "sarah", string)
print(new_string)
# Out:
# sarah

# %%
customer_reviews = [
    "sam was a great help to me in the store",
    "the cashier was very rude to me, I think her name was eleanor",
    "amazing work from sadeen!",
    "sarah was able to help me find the items i needed quickly",
    "lucy is such a great addition to the team",
    "great service from sara she found me what i wanted",
]

# %%
sarah_reviews = []

# %%
pattern_to_find = r"sarah?"

# %%
sarah_reviews = [
    review
    for review in customer_reviews
    if re.search(pattern_to_find, review) is not None
]

# %%
print(sarah_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
a_reviews = []

# %%
a_pattern = r"^a"

# %%
a_reviews = [review for review in customer_reviews if re.search(a_pattern, review)]

# %%
print(a_reviews)
# Out:
# ['amazing work from sadeen!']

# %%
y_pattern = r"y$"

# %%
y_reviews = [review for review in customer_reviews if re.search(y_pattern, review)]

# %%
print(y_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly']

# %%
needwant_reviews = []
pattern_to_find = r"(need|want)ed"

needwant_reviews = [
    review for review in customer_reviews if re.search(pattern_to_find, review)
]

print(needwant_reviews)
# Out:
# ['sarah was able to help me find the items i needed quickly', 'great service from sara she found me what i wanted']

# %%
no_punct_reviews = []
pattern_to_find = r"[^\w\s]"

# %%
needwant_reviews = [re.sub(pattern_to_find, "", review) for review in customer_reviews]

print(needwant_reviews)
# Out:
# ['the cashier was very rude to me, I think her name was eleanor', 'amazing work from sadeen!']
